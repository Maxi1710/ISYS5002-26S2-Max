# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxi1710/ISYS5002-26S2-Max/blob/main/Max.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")

print()

print("This is the first line. \nThis is the second line.")

print('''Three quotes can be used also
to print multiple lines using a single print function''')
# Out:
# Hello, World!
#
# This is the first line.
# This is the second line.
# Three quotes can be used also
# to print multiple lines using a single print function
